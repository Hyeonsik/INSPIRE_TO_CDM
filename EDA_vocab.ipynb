# %% [markdown]
# ## EDA

# %%
df_concept_rel
# Out:
#           concept_id_1  concept_id_2 relationship_id  valid_start_date  \
# 0             35977770      35973310     Mapped from          20200912
# 1             35977770      35977770     Mapped from          20200913
# 2             35977770      35977770         Maps to          20200913
# 3             35977772      35977772     Mapped from          20200913
# 4             35977772      35977772         Maps to          20200913
# ...                ...           ...             ...               ...
# 60071339      35977746      35977746         Maps to          20200913
# 60071340      35977751      35977751     Mapped from          20200913
# 60071341      35977751      35977751         Maps to          20200913
# 60071342      35977754      35977754     Mapped from          20200913
# 60071343      35977754      35977754         Maps to          20200913
#
#           valid_end_date  invalid_reason
# 0               20991231             NaN
# 1               20991231             NaN
# 2               20991231             NaN
# 3               20991231             NaN
# 4               20991231             NaN
# ...                  ...             ...
# 60071339        20991231             NaN
# 60071340        20991231             NaN
# 60071341        20991231             NaN
# 60071342        20991231             NaN
# 60071343        20991231             NaN
#
# [60071344 rows x 6 columns]

# %%
df_vocab
# Out:
#        vocabulary_id                                    vocabulary_name  \
# 0       Episode Type                                  OMOP Episode Type
# 1    Obs Period Type                       OMOP Observation Period Type
# 2              CIViC  Clinical Interpretation of Variants in Cancer ...
# 3             OncoKB                      Oncology Knowledge Base (MSK)
# 4               ABMS  Provider Specialty (American Board of Medical ...
# ..               ...                                                ...
# 121              MMI                         Modernizing Medicine (MMI)
# 122              SMQ                 Standardised MedDRA Queries (MSSO)
# 123           Gender                                        OMOP Gender
# 124        GCN_SEQNO                      Clinical Formulation ID (FDB)
# 125            LOINC  Logical Observation Identifiers Names and Code...
#
#                                   vocabulary_reference vocabulary_version  \
# 0                                       OMOP generated                NaN
# 1                                       OMOP generated                NaN
# 2    https://github.com/griffithlab/civic-server/bl...   CIViC 2022-10-01
# 3                              https://www.oncokb.org/   OncoKB v20210502
# 4    http://www.abms.org/member-boards/specialty-su...    2018-06-26 ABMS
# ..                                                 ...                ...
# 121                                    MMI proprietary                NaN
# 122  http://www.meddramsso.com/secure/smq/SMQ_Sprea...       Version 14.0
# 123                                     OMOP generated                NaN
# 124                        FDB US distribution package   20151119 Release
# 125                   http://loinc.org/downloads/loinc         LOINC 2.75
#
#      vocabulary_concept_id
# 0                    32542
# 1                 44819149
# 2                    32913
# 3                    32999
# 4                 45756746
# ..                     ...
# 121                 581367
# 122               44819121
# 123               44819108
# 124               44819141
# 125               44819102
#
# [126 rows x 5 columns]

# %%
df_vocab[df_vocab['vocabulary_id']=='ICD10CM']
# Out:
#    vocabulary_id                                    vocabulary_name  \
# 13       ICD10CM  International Classification of Diseases, Tent...
#
#                           vocabulary_reference  \
# 13  https://www.cdc.gov/nchs/icd/icd-10-cm.htm
#
#                   vocabulary_version  vocabulary_concept_id
# 13  ICD10CM FY2023 code descriptions               44819098

# %%
df_concept = pd.read_csv(f'vocab/CONCEPT.csv', sep='\t')

# %%
df_concept
# Out:
#          concept_id                                       concept_name  \
# 0          45756805                               Pediatric Cardiology
# 1          45756804                           Pediatric Anesthesiology
# 2          45756803            Pathology-Anatomic / Pathology-Clinical
# 3          45756802                              Pathology - Pediatric
# 4          45756801                      Pathology - Molecular Genetic
# ...             ...                                                ...
# 9154804     2213270  Molecular cytogenetics; chromosomal in situ hy...
# 9154805    45889102                         Bone graft, any donor area
# 9154806     2213271  Molecular cytogenetics; chromosomal in situ hy...
# 9154807     2213272  Molecular cytogenetics; interphase in situ hyb...
# 9154808    45889100  Excision, coccygeal pressure ulcer, with coccy...
#
#            domain_id vocabulary_id     concept_class_id standard_concept  \
# 0           Provider          ABMS  Physician Specialty                S
# 1           Provider          ABMS  Physician Specialty                S
# 2           Provider          ABMS  Physician Specialty                S
# 3           Provider          ABMS  Physician Specialty                S
# 4           Provider          ABMS  Physician Specialty                S
# ...              ...           ...                  ...              ...
# 9154804  Measurement          CPT4                 CPT4                S
# 9154805    Procedure          CPT4       CPT4 Hierarchy                C
# 9154806  Measurement          CPT4                 CPT4                S
# 9154807  Measurement          CPT4                 CPT4                S
# 9154808    Procedure          CPT4       CPT4 Hierarchy                C
#
#         concept_code  valid_start_date  valid_end_date invalid_reason
# 0        OMOP4821938          19700101        20991231            NaN
# 1        OMOP4821939          19700101        20991231            NaN
# 2        OMOP4821940          19700101        20991231            NaN
# 3        OMOP4821941          19700101        20991231            NaN
# 4        OMOP4821942          19700101        20991231            NaN
# ...              ...               ...             ...            ...
# 9154804        88272          19700101        20991231            NaN
# 9154805      1003752          20141010        20991231            NaN
# 9154806        88273          19700101        20991231            NaN
# 9154807        88274          19700101        20991231            NaN
# 9154808      1003535          20141010        20991231            NaN
#
# [9154809 rows x 10 columns]

# %%
df_concept[df_concept['concept_name']=='Asian']
# Out:
#          concept_id concept_name    domain_id vocabulary_id concept_class_id  \
# 271338      3959336        Asian  Observation    CO-CONNECT             Race
# 1600431    45879439        Asian   Meas Value         LOINC           Answer
# 2076521    19388613        Asian  Observation          MeSH     Main Heading
# 4333980    44814655        Asian  Observation       PCORNet             Race
# 4340650        8515        Asian         Race          Race             Race
#
#         standard_concept      concept_code  valid_start_date  valid_end_date  \
# 271338               NaN  CC-ETHNICITY-018          20220101        20991231
# 1600431                S          LA6156-9          19700101        20991231
# 2076521              NaN           D001213          20230501        20991231
# 4333980              NaN           Race-02          19700101        20991231
# 4340650                S                 2          19700101        20991231
#
#         invalid_reason
# 271338             NaN
# 1600431            NaN
# 2076521            NaN
# 4333980            NaN
# 4340650            NaN

# %%
df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']=='I21')]
# Out:
#         concept_id                 concept_name  domain_id vocabulary_id  \
# 913681     1569126  Acute myocardial infarction  Condition       ICD10CM
#
#            concept_class_id standard_concept concept_code  valid_start_date  \
# 913681  3-char nonbill code              NaN          I21          20120101
#
#         valid_end_date invalid_reason
# 913681        20991231            NaN

# %%
df_concept[(df_concept['concept_code']=='I21')]
# Out:
#          concept_id                 concept_name  domain_id vocabulary_id  \
# 261763     37605728  Acute myocardial infarction  Condition         CIM10
# 889877     45538370  Acute myocardial infarction  Condition         ICD10
# 913681      1569126  Acute myocardial infarction  Condition       ICD10CM
# 1011692     1413785  Acute myocardial infarction  Condition       ICD10CN
# 1039726    37084476  Acute myocardial infarction  Condition       ICD10GM
# 1398921    42488360  Acute myocardial infarction  Condition          KCD7
#
#             concept_class_id standard_concept concept_code  valid_start_date  \
# 261763       ICD10 Hierarchy              NaN          I21          20191021
# 889877       ICD10 Hierarchy              NaN          I21          19900501
# 913681   3-char nonbill code              NaN          I21          20120101
# 1011692      ICD10 Hierarchy              NaN          I21          20160101
# 1039726      ICD10 Hierarchy              NaN          I21          20000101
# 1398921            KCD7 code              NaN          I21          20170701
#
#          valid_end_date invalid_reason
# 261763         20991231            NaN
# 889877         20991231            NaN
# 913681         20991231            NaN
# 1011692        20991231            NaN
# 1039726        20991231            NaN
# 1398921        20991231            NaN

# %%
df_concept[df_concept['concept_id']==312327]
# Out:
#          concept_id                 concept_name  domain_id vocabulary_id  \
# 7742627      312327  Acute myocardial infarction  Condition        SNOMED
#
#          concept_class_id standard_concept concept_code  valid_start_date  \
# 7742627  Clinical Finding                S     57054005          20020131
#
#          valid_end_date invalid_reason
# 7742627        20991231            NaN

# %%
df_concept_rel[(df_concept_rel['concept_id_1']==1569126) & (df_concept_rel['relationship_id']=='Maps to')]
# Out:
#           concept_id_1  concept_id_2 relationship_id  valid_start_date  \
# 14316077       1569126        312327         Maps to          20190109
#
#           valid_end_date  invalid_reason
# 14316077        20991231             NaN

# %%
import time

start = time.time()
df_concept_rel[(df_concept_rel['concept_id_1']==1569126) & (df_concept_rel['relationship_id']=='Maps to')]
print(time.time() - start)
# Out:
# 3.184921979904175

# %%
start = time.time()
df_concept_rel.query("concept_id_1 == 1569126 and relationship_id == 'Maps to'")
print(time.time() - start)
# Out:
# 3.417990207672119

# %% [markdown]
# # Vocab Mapping
# * Mapping source concept into standard concept

# %%
import csv
import pandas as pd

df_vocab = pd.read_csv(f'vocab/VOCABULARY.csv', sep='\t', on_bad_lines='error')
df_concept_rel = pd.read_csv(f'vocab/CONCEPT_RELATIONSHIP.csv', sep='\t', on_bad_lines='error')
df_concept = pd.read_csv(f'vocab/CONCEPT.csv', sep='\t')
# Out:
# /tmp/ipykernel_519938/1335861446.py:6: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_concept = pd.read_csv(f'vocab/CONCEPT.csv', sep='\t')

# %% [markdown]
# ## diagnosis

# %%
# INSPIRE v0.2 (about 65,000 cases, 50% of the surgical cases)
import pandas as pd
import numpy as np

# loading INSPIRE dataset (6 source tables)
input_path = 'inspire_v2'
df_diag = pd.read_csv(f'{input_path}/diagnosis.csv')

# %%
df_diag
# Out:
#          subject_id  chart_time icd10_cm
# 0         190852492      325440      R06
# 1         190852492      325440      G20
# 2         142367193           0      I61
# 3         142367193      658080      E11
# 4         142367193      658080      G44
# ...             ...         ...      ...
# 4733041   195448932      172800      H02
# 4733042   195448932      172800      L90
# 4733043   195448932      172800      S04
# 4733044   155658270       24480      K81
# 4733045   155658270       34560      K81
#
# [4733046 rows x 3 columns]

# %%
import pandas as pd

# Create a filtered DataFrame for 'Maps to' relationships
maps_to_df = df_concept_rel[df_concept_rel['relationship_id'] == 'Maps to']

# Merge df_data with df_concept to get source_concept_id
merged_data = df_diag.merge(df_concept[df_concept['vocabulary_id'] == 'ICD10CM'], left_on='icd10_cm', right_on='concept_code')

# Merge the result with maps_to_df to get standard_concept_id
final_result = merged_data.merge(maps_to_df, left_on='concept_id', right_on='concept_id_1')

# check if there is cases that fails to map
nan_sum = df_diag_mapped['standard_concept_id'].isna().sum()
print(f'null match cases: {nan_sum}')

# Reconstruct the merged dataframe and save
df_diag_mapped = final_result[['subject_id', 'chart_time', 'icd10_cm', 'concept_id', 'concept_id_2']]
df_diag_mapped.rename(columns = {'icd10_cm' : 'source_value', 'concept_id': 'source_concept_id', 'concept_id_2' : 'standard_concept_id'}, inplace=True)
df_diag_mapped.to_csv('inspire_v2/mapped/diagnosis.csv')

# %% [markdown]
# ### trials of multiprocessing

# %%
def diagnosis_map(df_data):
    for idx, row in tqdm(df_data.iterrows(), total=df_data.shape[0]):
        try:
            source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
            standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
            df_data.loc[idx, 'standard_concept_id'] = int(standard_concept_id)

        except Exception as e:
            #print(e)
            df_data.loc[idx, 'standard_concept_id'] = np.nan
        
    return df_data

# %%
import multiprocessing as mp

num_cores = 32
df_diag = pd.read_csv(f'{input_path}/diagnosis.csv')

def multiprocess_mapping(df_diag, num_cores):
    # split the dataframe into num_cores part
    df_split = np.array_split(df_diag[:], num_cores)

    # create a pool of process
    pool = mp.Pool(num_cores)

    # apply the function on each part of the dataframe
    df = pd.concat(pool.map(diagnosis_map, df_split))

    pool.close()
    pool.join()
    
    return df

# %%
from tqdm import tqdm

df_map = pd.DataFrame()

naug = int(len(df_diag)/1000)
print(naug)
for i in (range(naug)):
    print(i)
    df_map = pd.concat([df_map, multiprocess_mapping(df_diag.loc[i*naug:(i+1)*naug], 32)])
# Out:
# 4733
# 0
#  73%|███████▎  | 108/148 [08:30<03:09,  4.73s/it]
# Process ForkPoolWorker-117:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#
# KeyboardInterrupt
#
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#  73%|███████▎  | 108/148 [08:30<03:09,  4.73s/it]KeyboardInterrupt
#
# Process ForkPoolWorker-107:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  72%|███████▏  | 106/148 [08:30<03:22,  4.82s/it]
# Process ForkPoolWorker-119:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  71%|███████   | 105/148 [08:30<03:29,  4.86s/it]
# Process ForkPoolWorker-121:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  74%|███████▎  | 109/148 [08:30<03:02,  4.69s/it]
# Process ForkPoolWorker-118:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#  72%|███████▏  | 107/148 [08:30<03:15,  4.77s/it]  File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
# Process ForkPoolWorker-99:
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  72%|███████▏  | 106/148 [08:30<03:22,  4.82s/it]
# Process ForkPoolWorker-120:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#  74%|███████▍  | 110/148 [08:30<02:56,  4.64s/it]  File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#
#
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# Process ForkPoolWorker-106:
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
# Process ForkPoolWorker-103:
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
# Traceback (most recent call last):
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
# KeyboardInterrupt
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  74%|███████▎  | 109/148 [08:31<03:02,  4.69s/it]
#
#
#
# Process ForkPoolWorker-115:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-113:
# Process ForkPoolWorker-122:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#  70%|███████   | 104/148 [08:31<03:36,  4.91s/it]  File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
# Process ForkPoolWorker-98:
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
# Process ForkPoolWorker-125:
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#  74%|███████▍  | 109/147 [08:31<02:58,  4.69s/it]
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Process ForkPoolWorker-128:
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
# Traceback (most recent call last):
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#   File "/tmp/ipykernel_519938/2008242463.py", line 4, in diagnosis_map
#     source_concept_id = df_concept[(df_concept['vocabulary_id']=='ICD10CM') & (df_concept['concept_code']==row['icd10_cm'])]['concept_id'].values[0]
# KeyboardInterrupt
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
# KeyboardInterrupt
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  70%|██████▉   | 103/148 [08:31<03:43,  4.97s/it]
# Process ForkPoolWorker-123:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#  74%|███████▎  | 109/148 [08:31<03:03,  4.69s/it]Exception ignored in: <generator object tqdm.__iter__ at 0x7f997bc9f4a0>
# Traceback (most recent call last):
#   File "/home/hskim1/.local/lib/python3.8/site-packages/tqdm/std.py", line 1197, in __iter__
#     self.close()
#   File "/home/hskim1/.local/lib/python3.8/site-packages/tqdm/std.py", line 1303, in close
#   File "/home/hskim1/.local/lib/python3.8/site-packages/tqdm/std.py", line 1496, in display
#         self.sp(self.__str__() if msg is None else msg)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/tqdm/std.py", line 462, in print_status
#       File "/home/hskim1/.local/lib/python3.8/site-packages/tqdm/std.py", line 455, in fp_write
#     fp.write(str(s))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/tqdm/utils.py", line 195, in inner
#  73%|███████▎  | 108/148 [08:31<03:09,  4.74s/it]
# return func(*args, **kwargs)Process ForkPoolWorker-100:
#
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 646, in write
# Traceback (most recent call last):
#       File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 253, in schedule
#     f()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 604, in _flush
#     self.session.send(
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/jupyter_client/session.py", line 859, in send
#     stream.send_multipart(to_send, copy=copy)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 260, in send_multipart
#     self.schedule(lambda: self._really_send(*args, **kwargs))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 253, in schedule
#  70%|██████▉   | 103/148 [08:32<03:43,  4.97s/it]
#
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 260, in <lambda>
# Process ForkPoolWorker-102:
#     self.schedule(lambda: self._really_send(*args, **kwargs))Traceback (most recent call last):
#
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/ipykernel/iostream.py", line 279, in _really_send
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#       File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
# ctx.term()  File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/site-packages/zmq/sugar/context.py", line 192, in term
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#       File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
# super().term()  File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#
# KeyboardInterrupt
#   File "zmq/backend/cython/context.pyx", line 83, in zmq.backend.cython.context.Context.term
#   File "zmq/backend/cython/checkrc.pxd", line 13, in zmq.backend.cython.checkrc._check_rc
# KeyboardInterrupt:
# Process ForkPoolWorker-97:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  73%|███████▎  | 108/148 [08:32<03:09,  4.74s/it]
# Process ForkPoolWorker-105:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  73%|███████▎  | 108/148 [08:32<03:09,  4.74s/it]
#
# Process ForkPoolWorker-116:
# Process ForkPoolWorker-124:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#  75%|███████▌  | 111/148 [08:32<02:50,  4.62s/it]
# Process ForkPoolWorker-109:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
#
#  70%|██████▉   | 103/148 [08:32<03:43,  4.97s/it]KeyboardInterrupt
# Process ForkPoolWorker-108:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  74%|███████▍  | 110/148 [08:32<02:57,  4.66s/it]
# Process ForkPoolWorker-126:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  73%|███████▎  | 108/148 [08:32<03:09,  4.75s/it]
# Process ForkPoolWorker-101:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  72%|███████▏  | 106/148 [08:32<03:23,  4.84s/it]
# Process ForkPoolWorker-112:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#  73%|███████▎  | 108/148 [08:32<03:09,  4.75s/it]  File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# Process ForkPoolWorker-111:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  71%|███████   | 105/148 [08:33<03:30,  4.89s/it]
# Process ForkPoolWorker-114:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  77%|███████▋  | 114/148 [08:33<02:33,  4.50s/it]
# Process ForkPoolWorker-110:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt
#  73%|███████▎  | 108/147 [08:33<03:05,  4.76s/it]
# Process ForkPoolWorker-127:
# Traceback (most recent call last):
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/opt/anaconda-3-2020.02/envs/hskim/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_519938/2008242463.py", line 5, in diagnosis_map
#     standard_concept_id = df_concept_rel[(df_concept_rel['concept_id_1']==source_concept_id) & (df_concept_rel['relationship_id']=='Maps to')]['concept_id_2'].values[0]
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/common.py", line 81, in new_method
#     return method(self, other)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/arraylike.py", line 40, in __eq__
#     return self._cmp_method(other, operator.eq)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/series.py", line 6096, in _cmp_method
#     res_values = ops.comparison_op(lvalues, rvalues, op)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 293, in comparison_op
#     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#   File "/home/hskim1/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py", line 82, in comp_method_OBJECT_ARRAY
#     result = libops.scalar_compare(x.ravel(), y, op)
# KeyboardInterrupt

# %% [markdown]
# ## medications

# %%
# INSPIRE v0.2 (about 65,000 cases, 50% of the surgical cases)
import pandas as pd
import numpy as np

# loading INSPIRE dataset (6 source tables)
input_path = 'inspire_v2'
df_med = pd.read_csv(f'{input_path}/medications.csv')

# %%
df_med
# Out:
#          subject_id  chart_time           drug_name route
# 0         117512122     2832985          pregabalin    po
# 1         117512122     2833610          pregabalin    po
# 2         117512122     2832985       levetiracetam    po
# 3         117512122     2833610       levetiracetam    po
# 4         117512122     2832985          famotidine    po
# ...             ...         ...                 ...   ...
# 9926789   127026720        2070           ofloxacin    ex
# 9926790   127026720        2550  ibuprofen/arginine    po
# 9926791   127026720        1340      levocetirizine    po
# 9926792   154044684         675          gentamicin    iv
# 9926793   154044684         675           cefazolin    iv
#
# [9926794 rows x 4 columns]

# %%
# Map the source concept of drugs into standard concept (RxNorm)
df_med_mapped = df_med.merge(df_concept[(df_concept['vocabulary_id'] == 'RxNorm') & (df_concept['standard_concept'] == 'S')][['concept_name', 'concept_id']], left_on='drug_name', right_on='concept_name')

# check if there is cases that fails to map
nan_sum = df_med_mapped['concept_id'].isna().sum()
print(f'null match cases: {nan_sum}')

df_med_mapped.to_csv('inspire_v2/mapped/medications.csv')
# Out:
# null match cases: 0

# %% [markdown]
# ## labs

# %%
# INSPIRE v0.2 (about 65,000 cases, 50% of the surgical cases)
import pandas as pd
import numpy as np

# loading INSPIRE dataset (6 source tables)
input_path = 'inspire_v2'
df_labs = pd.read_csv(f'{input_path}/labs.csv')
df_params = pd.read_csv(f'{input_path}/parameters.csv', sep='\t')

# %%
df_labs = df_labs.merge(df_params[['Label', 'concept_id']], left_on = 'item_name', right_on = 'Label')
#df_labs_mapped = df_labs.merge(df_concept[(df_concept['vocabulary_id'] == 'ROINC') & (df_concept['standard_concept'] == 'S')][['concept_name', 'concept_id']], left_on='drug_name', right_on='concept_name')
# Out:
#           subject_id  chart_time      item_name    value          Label  \
# 0          133338290       86155  total_protein     7.00  total_protein
# 1          196268171      309430  total_protein     6.90  total_protein
# 2          113823093       45825  total_protein     4.80  total_protein
# 3          113823093       46585  total_protein     4.40  total_protein
# 4          113823093       47925  total_protein     4.70  total_protein
# ...              ...         ...            ...      ...            ...
# 21367126   130256661        -170        d_dimer  1470.00        d_dimer
# 21367127   138645201        -385        d_dimer   369.00        d_dimer
# 21367128   185797124         950        d_dimer  2620.00        d_dimer
# 21367129   127146444      -16735        d_dimer     1.57        d_dimer
# 21367130   199434220        8205        d_dimer     0.14        d_dimer
#
#           concept_id
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 21367126         NaN
# 21367127         NaN
# 21367128         NaN
# 21367129         NaN
# 21367130         NaN
#
# [21367131 rows x 6 columns]

# %% [markdown]
# ## vitals

# %% [markdown]
# ## ward_vitals

# %%
df_concept
# Out:
#          concept_id                                       concept_name  \
# 0          45756805                               Pediatric Cardiology
# 1          45756804                           Pediatric Anesthesiology
# 2          45756803            Pathology-Anatomic / Pathology-Clinical
# 3          45756802                              Pathology - Pediatric
# 4          45756801                      Pathology - Molecular Genetic
# ...             ...                                                ...
# 9154804     2213270  Molecular cytogenetics; chromosomal in situ hy...
# 9154805    45889102                         Bone graft, any donor area
# 9154806     2213271  Molecular cytogenetics; chromosomal in situ hy...
# 9154807     2213272  Molecular cytogenetics; interphase in situ hyb...
# 9154808    45889100  Excision, coccygeal pressure ulcer, with coccy...
#
#            domain_id vocabulary_id     concept_class_id standard_concept  \
# 0           Provider          ABMS  Physician Specialty                S
# 1           Provider          ABMS  Physician Specialty                S
# 2           Provider          ABMS  Physician Specialty                S
# 3           Provider          ABMS  Physician Specialty                S
# 4           Provider          ABMS  Physician Specialty                S
# ...              ...           ...                  ...              ...
# 9154804  Measurement          CPT4                 CPT4                S
# 9154805    Procedure          CPT4       CPT4 Hierarchy                C
# 9154806  Measurement          CPT4                 CPT4                S
# 9154807  Measurement          CPT4                 CPT4                S
# 9154808    Procedure          CPT4       CPT4 Hierarchy                C
#
#         concept_code  valid_start_date  valid_end_date invalid_reason
# 0        OMOP4821938          19700101        20991231            NaN
# 1        OMOP4821939          19700101        20991231            NaN
# 2        OMOP4821940          19700101        20991231            NaN
# 3        OMOP4821941          19700101        20991231            NaN
# 4        OMOP4821942          19700101        20991231            NaN
# ...              ...               ...             ...            ...
# 9154804        88272          19700101        20991231            NaN
# 9154805      1003752          20141010        20991231            NaN
# 9154806        88273          19700101        20991231            NaN
# 9154807        88274          19700101        20991231            NaN
# 9154808      1003535          20141010        20991231            NaN
#
# [9154809 rows x 10 columns]

# %%
# !pip install youtube-dl
# Out:
# /bin/bash: /opt/anaconda-3-2020.02/envs/hskim/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting youtube-dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 12.5 MB/s
# Installing collected packages: youtube-dl
#   WARNING: The script youtube-dl is installed in '/home/hskim1/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed youtube-dl-2021.12.17
# WARNING: You are using pip version 21.3.1; however, version 23.2.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
